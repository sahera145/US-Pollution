# %% [markdown]
# ## Importing Libraries

# %%
#Import Libraries
import pandas as pd
import numpy as mp
import os

# %% [markdown]
# ## Importing Data Sets

# %%
path=r'C:\Users\sasze\Documents\Careerfoundry Data Analytics\Achievement 6'

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'pollution_us_2000_2016.csv'), index_col = False)

# %% [markdown]
# ## Checking Data

# %%
df.shape
# Out:
# (1048575, 29)

# %%
df.head()
# Out:
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           0           4           13      3002
# 1           1           4           13      3002
# 2           2           4           13      3002
# 3           3           4           13      3002
# 4           4           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#   Date Local          NO2 Units  ...          SO2 Units  SO2 Mean  \
# 0   1/1/2000  Parts per billion  ...  Parts per billion  3.000000
# 1   1/1/2000  Parts per billion  ...  Parts per billion  3.000000
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# State Code             int64
# County Code            int64
# Site Num               int64
# Address               object
# State                 object
# County                object
# City                  object
# Date Local            object
# NO2 Units             object
# NO2 Mean             float64
# NO2 1st Max Value    float64
# NO2 1st Max Hour       int64
# NO2 AQI                int64
# O3 Units              object
# O3 Mean              float64
# O3 1st Max Value     float64
# O3 1st Max Hour        int64
# O3 AQI                 int64
# SO2 Units             object
# SO2 Mean             float64
# SO2 1st Max Value    float64
# SO2 1st Max Hour       int64
# SO2 AQI              float64
# CO Units              object
# CO Mean              float64
# CO 1st Max Value     float64
# CO 1st Max Hour        int64
# CO AQI               float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'State Code', 'County Code', 'Site Num', 'Address',
#        'State', 'County', 'City', 'Date Local', 'NO2 Units', 'NO2 Mean',
#        'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI', 'O3 Units',
#        'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'SO2 Units',
#        'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
#        'CO Units', 'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI'],
#       dtype='object')

# %% [markdown]
# ## Data Wrangling

# %%
#Drop columns that aren't necessary
df=df.drop(columns=['Unnamed: 0', 'State Code', 'County Code', 'Site Num', 'Address', 'County', 'City', 'Date Local', 'NO2 Units', 'O3 Units', 'SO2 Units','CO Units'])

# %%
df.shape
# Out:
# (1048575, 17)

# %%
df.head()
# Out:
#      State   NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI   O3 Mean  \
# 0  Arizona  19.041667               49.0                19       46  0.022500
# 1  Arizona  19.041667               49.0                19       46  0.022500
# 2  Arizona  19.041667               49.0                19       46  0.022500
# 3  Arizona  19.041667               49.0                19       46  0.022500
# 4  Arizona  22.958333               36.0                19       34  0.013375
#
#    O3 1st Max Value  O3 1st Max Hour  O3 AQI  SO2 Mean  SO2 1st Max Value  \
# 0             0.040               10      34  3.000000                9.0
# 1             0.040               10      34  3.000000                9.0
# 2             0.040               10      34  2.975000                6.6
# 3             0.040               10      34  2.975000                6.6
# 4             0.032               10      27  1.958333                3.0
#
# ...

# %% [markdown]
# ## Missing Values

# %%
#find missing values
df.isnull().sum()
# Out:
# State                     0
# NO2 Mean                  0
# NO2 1st Max Value         0
# NO2 1st Max Hour          0
# NO2 AQI                   0
# O3 Mean                   0
# O3 1st Max Value          0
# O3 1st Max Hour           0
# O3 AQI                    0
# SO2 Mean                  0
# SO2 1st Max Value         0
# SO2 1st Max Hour          0
# SO2 AQI              524086
# CO Mean                   0
# CO 1st Max Value          0
# CO 1st Max Hour           0
# CO AQI               524223
# dtype: int64

# %% [markdown]
# ## Duplicates

# %%
df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
#             State   NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  \
# 54236    Kentucky  13.173913               29.0                 5       27
# 54237    Kentucky  13.173913               29.0                 5       27
# 54238    Kentucky  13.173913               29.0                 5       27
# 54239    Kentucky  13.173913               29.0                 5       27
# 54248    Kentucky  13.869565               24.0                 2       23
# ...           ...        ...                ...               ...      ...
# 1013072  Colorado   4.869565               20.0                 5       19
# 1013081  Colorado  10.043478               42.0                 6       40
# 1013082  Colorado  10.043478               42.0                 6       40
# 1013083  Colorado  10.043478               42.0                 6       40
# 1013084  Colorado  10.043478               42.0                 6       40
#
# ...

# %%
df_clean=df.drop_duplicates()

# %%
df_clean.shape
# Out:
# (1046128, 17)

# %% [markdown]
# ## Descriptive Statistics

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1046128 entries, 0 to 1048574
# Data columns (total 17 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   State              1046128 non-null  object
#  1   NO2 Mean           1046128 non-null  float64
#  2   NO2 1st Max Value  1046128 non-null  float64
#  3   NO2 1st Max Hour   1046128 non-null  int64
#  4   NO2 AQI            1046128 non-null  int64
#  5   O3 Mean            1046128 non-null  float64
#  6   O3 1st Max Value   1046128 non-null  float64
#  7   O3 1st Max Hour    1046128 non-null  int64
#  8   O3 AQI             1046128 non-null  int64
#  9   SO2 Mean           1046128 non-null  float64
#  10  SO2 1st Max Value  1046128 non-null  float64
#  11  SO2 1st Max Hour   1046128 non-null  int64
#  12  SO2 AQI            523265 non-null   float64
#  13  CO Mean            1046128 non-null  float64
#  14  CO 1st Max Value   1046128 non-null  float64
# ...

# %%
df_cleaned=df_clean

# %%
df_cleaned.shape
# Out:
# (1046128, 17)

# %%
df_cleaned.to_csv(os.path.join(path, '02 Data','Prepared Data', 'us_pollution_cleaned.csv'))
